# %% [markdown]
# # Download The preprocessed dataset for our working

# %%
! wget https://raw.githubusercontent.com/datascienceinc/learn-data-science/master/Introduction-to-K-means-Clustering/Data/data_1024.csv
# Out:
# --2019-05-31 09:07:40--  https://raw.githubusercontent.com/datascienceinc/learn-data-science/master/Introduction-to-K-means-Clustering/Data/data_1024.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85448 (83K) [text/plain]
# Saving to: ‘data_1024.csv.1’
#
# data_1024.csv.1     100%[===================>]  83.45K  --.-KB/s    in 0.02s
#
# 2019-05-31 09:07:40 (5.39 MB/s) - ‘data_1024.csv.1’ saved [85448/85448]

# %% [markdown]
# # Load The data

# %%
import pandas as pd
df=pd.read_csv("data_1024.csv",sep="\t")

# %%
df.head(3)
# Out:
#     Driver_ID  Distance_Feature  Speeding_Feature
# 0  3423311935             71.24              28.0
# 1  3423313212             52.53              25.0
# 2  3423313724             64.54              27.0

# %% [markdown]
# # Visualliozation of data
#
# The chart below shows the dataset for 4,000 drivers, with the distance feature on the x-axis and speeding feature on the y-axis.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,6))
plt.scatter(df["Distance_Feature"],df["Speeding_Feature"])
plt.xlabel("Distance_Feature")
plt.ylabel("Speeding_Feature")
# Out:
# Text(0, 0.5, 'Speeding_Feature')

# %% [markdown]
# # Choose K and Run the Algorithm
# Start by choosing K=2. For this example

# %%
#@title run the cell
import numpy as np
from sklearn.cluster import KMeans

### For the purposes of this example, we store feature data from our
### dataframe `df`, in the `f1` and `f2` arrays. We combine this into
### a feature matrix `X` before entering it into the algorithm.
f1 = df['Distance_Feature'].values
f2 = df['Speeding_Feature'].values

X=np.matrix(list(zip(f1,f2)))
kmeans = KMeans(n_clusters=2).fit(X)
y_kmeans = kmeans.predict(X)
plt.figure(figsize=(15,6))
plt.scatter(df["Distance_Feature"],df["Speeding_Feature"],c=y_kmeans)
plt.xlabel("Distance_Feature")
plt.ylabel("Speeding_Feature")


centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# # K=4

# %%
#@title run the cell
kmeans = KMeans(n_clusters=4).fit(X)
y_kmeans = kmeans.predict(X)
plt.figure(figsize=(15,6))
plt.scatter(df["Distance_Feature"],df["Speeding_Feature"],c=y_kmeans)
plt.xlabel("Distance_Feature")
plt.ylabel("Speeding_Feature")


centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# # k=8

# %%
#@title run the cell

kmeans = KMeans(n_clusters=8).fit(X)
y_kmeans = kmeans.predict(X)
plt.figure(figsize=(15,6))
plt.scatter(df["Distance_Feature"],df["Speeding_Feature"],c=y_kmeans)
plt.xlabel("Distance_Feature")
plt.ylabel("Speeding_Feature")


centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# # K=11

# %%
#@title run the cell
kmeans = KMeans(n_clusters=11).fit(X)
y_kmeans = kmeans.predict(X)
plt.figure(figsize=(15,6))
plt.scatter(df["Distance_Feature"],df["Speeding_Feature"],c=y_kmeans)
plt.xlabel("Distance_Feature")
plt.ylabel("Speeding_Feature")


centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
